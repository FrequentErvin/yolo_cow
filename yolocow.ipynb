# %% [markdown]
# <a href="https://colab.research.google.com/github/FrequentErvin/yolo_cow/blob/main/yolocow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12270, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 12270 (delta 5), reused 9 (delta 1), pack-reused 12250
# Receiving objects: 100% (12270/12270), 12.04 MiB | 29.08 MiB/s, done.
# Resolving deltas: 100% (8491/8491), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 9.2 MB/s
# Setup complete. Using torch 1.11.0+cu113 (Tesla T4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.environ["DATASET_DIRECTORY"] = "/content/drive/MyDrive/Cows-1"

# %%
# !python train.py --img 416 --batch 16 --epochs 150 --data /content/drive/MyDrive/Cows-1/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/Cows-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !zip -r /content/model.zip /content/yolov5/
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/export.py (deflated 73%)
#   adding: content/yolov5/val.py (deflated 67%)
#   adding: content/yolov5/data/ (stored 0%)
#   adding: content/yolov5/data/VisDrone.yaml (deflated 59%)
#   adding: content/yolov5/data/SKU-110K.yaml (deflated 52%)
#   adding: content/yolov5/data/hyps/ (stored 0%)
#   adding: content/yolov5/data/hyps/hyp.scratch-med.yaml (deflated 53%)
#   adding: content/yolov5/data/hyps/hyp.scratch-high.yaml (deflated 53%)
#   adding: content/yolov5/data/hyps/hyp.VOC.yaml (deflated 48%)
#   adding: content/yolov5/data/hyps/hyp.scratch-low.yaml (deflated 54%)
#   adding: content/yolov5/data/hyps/hyp.Objects365.yaml (deflated 40%)
#   adding: content/yolov5/data/images/ (stored 0%)
#   adding: content/yolov5/data/images/bus.jpg (deflated 1%)
#   adding: content/yolov5/data/images/zidane.jpg (deflated 0%)
#   adding: content/yolov5/data/coco128.yaml (deflated 50%)
# ...

# %%
from google.colab import files
files.download("/content/model.zip")

# %%
from google.colab import files
files.download("/content/k0706.zip")

# %%
# !git remote add origin https://github.com/FrequentErvin/yolo_cow.git
# !git branch -M main
# !git push -u origin main
# Out:
# fatal: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source /content/drive/MyDrive/exported_sorted/0706 --save-crop
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/exported_sorted/0706, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-259-ga2a1ed2 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/28 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0706/IMG_8787.jpeg: 416x320 Done. (0.015s)
# image 2/28 /content/drive/.shortcut-targets-by-id/1awX1z7P4-QpwCTMwjiw--AESkZnTfp9A/exported_sorted/0706/IMG_8788.jpeg: 416x320 1 muzzles, Done. (0.010s)
# ...

# %%
# !zip -r /content/k0706.zip /content/yolov5/runs/detect/exp/crops/muzzles
# Out:
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8797.jpg (deflated 1%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8810.jpg (deflated 1%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8788.jpg (deflated 2%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8799.jpg (deflated 1%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8798.jpg (deflated 2%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8805.jpg (deflated 2%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8793.jpg (deflated 2%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8807.jpg (deflated 2%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8794.jpg (deflated 2%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8790.jpg (deflated 2%)
#   adding: content/yolov5/runs/detect/exp/crops/muzzles/IMG_8800.jpg (deflated 1%)
# ...
